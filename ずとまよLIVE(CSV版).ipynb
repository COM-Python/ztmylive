# %%
import requests
import urllib
import pandas as pd
import folium
from folium.features import CustomIcon

df=pd.read_csv('/content/ずとまよLIVE歴Python.csv') #ファイルのパス適宜修正

width=40 #アイコン幅適宜修正
height=40 #アイコン高さ適宜修正
icon = CustomIcon(icon_image = '/content/icon.jpg',icon_size = (width, height),icon_anchor = (width/2, height/2),popup_anchor = (0, -height/2)) #マーカーアイコンのパス適宜修正

WIDTH = 500 #マーカー幅適宜修正

map=folium.Map(location=[35.690921, 139.700258], zoom_start=5)

makeurl="https://msearch.gsi.go.jp/address-search/AddressSearch?q=" #国土地理院APIリンク

for i,r in df.iterrows():
  s_quote=urllib.parse.quote(r['住所'])
  url=makeurl+s_quote
  response=requests.get(url)
  lon=response.json()[0]["geometry"]["coordinates"][0]
  lat=response.json()[0]["geometry"]["coordinates"][1]
  livespace = r['会場'].replace("\n", "<br />")
  livename = r['LIVE'].replace("\n", "<br />")
  popup_content = f"""
    <span style="color:purple; font-weight:bold; font-size:15px;">{livespace}</span><br />
    <span style="color:green;font-size:12px;">{livename}</span>
    """
  popup = folium.Popup(popup_content, max_width=WIDTH)
  folium.Marker(location=[lat,lon],popup=popup,icon=icon).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48895dcf7975f09c6618f6f9272c24bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48895dcf7975f09c6618f6f9272c24bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48895dcf7975f09c6618f6f9272c24bd = L.map(
#                 &quot;map_48895dcf7975f09c6618f6f9272c24bd&quot;,
#                 {
#                     center: [35.690921, 139.700258],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8dfb3408e4fac16496792bd056cca67f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8dfb3408e4fac16496792bd056cca67f.addTo(map_48895dcf7975f09c6618f6f9272c24bd);
#
#
#             var marker_9c803d2bd439db5e086f2443c0ad72a5 = L.marker(
#                 [35.668793, 139.701874],
#                 {
# }
#             ).addTo(map_48895dcf7975f09c6618f6f9272c24bd);
#
#
#         var icon_362ac981e5a7883309d46adeebe92dec = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/jpg;base64,...&quot;,
#   &quot;iconSize&quot;: [40, 40],
#   &quot;iconAnchor&quot;: [20.0, 20.0],
#   &quot;popupAnchor&quot;: [0, -20.0],
# });
#
#
#         var popup_4ba750b9bdbecc855aefcf2f6a426d61 = L.popup({
#   &quot;maxWidth&quot;: 500,
# });
#
#
#
#                 var html_d65d30f5d7e1ba740e1d8c799454329c = $(`&lt;div id=&quot;html_d65d30f5d7e1ba740e1d8c799454329c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;span style=&quot;color:purple; font-weight:bold; font-size:15px;&quot;&gt; 国立代々木競技場第一体育館&lt;/span&gt;&lt;br /&gt;     &lt;span style=&quot;color:green;font-size:12px;&quot;&gt;
# &lt;br /&gt;2023/01/14 ROAD GAME『テクノプア』~叢雲のつるぎ~
# &lt;br /&gt;2023/01/15 ROAD GAME『テクノプア』~叢雲のつるぎ~
# &lt;br /&gt;2025/05/17 YAKI YAKI YANKEE TOUR 続 「名巧は愚なるが如し」
# &lt;br /&gt;2025/05/18 YAKI YAKI YANKEE TOUR 続 「名巧は愚なるが如し」
# &lt;br /&gt;&lt;/span&gt;     &lt;/div&gt;`)[0];
#                 popup_4ba750b9bdbecc855aefcf2f6a426d61.setContent(html_d65d30f5d7e1ba740e1d8c799454329c);
#
#
#
#         marker_9c803d2bd439db5e086f2443c0ad72a5.bindPopup(popup_4ba750b9bdbecc855aefcf2f6a426d61)
#         ;
#
#
#
#
#                 marker_9c803d2bd439db5e086f2443c0ad72a5.setIcon(icon_362ac981e5a7883309d46adeebe92dec);
#
#
#             var marker_56cd9ddb66eb176bfc3d89ab1541bc6a = L.marker(
#                 [33.603218, 130.401825],
#                 {
# }
#             ).addTo(map_48895dcf7975f09c6618f6f9272c24bd);
#
#
#         var popup_5e0004ddf69239a8a9d762b7e6a4e3ea = L.popup({
#   &quot;maxWidth&quot;: 500,
# });
#
#
#
#                 var html_9b22b0e05b820b93ca029713bea30e9d = $(`&lt;div id=&quot;html_9b22b0e05b820b93ca029713bea30e9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;span style=&quot;color:purple; font-weight:bold; font-size:15px;&quot;&gt; 福岡国際センター&lt;/span&gt;&lt;br /&gt;     &lt;span style=&quot;color:green;font-size:12px;&quot;&gt;
# &lt;br /&gt;2025/05/10 YAKI YAKI YANKEE TOUR 続 「名巧は愚なるが如し」
# &lt;br /&gt;2025/05/11 YAKI YAKI YANKEE TOUR 続 「名巧は愚なるが如し」
# &lt;br /&gt;&lt;/span&gt;     &lt;/div&gt;`)[0];
#                 popup_5e0004ddf69239a8a9d762b7e6a4e3ea.setContent(html_9b22b0e05b820b93ca029713bea30e9d);
#
#
#
#         marker_56cd9ddb66eb176bfc3d89ab1541bc6a.bindPopup(popup_5e0004ddf69239a8a9d762b7e6a4e3ea)
#         ;
#
#
#
#
#                 marker_56cd9ddb66eb176bfc3d89ab1541bc6a.setIcon(icon_362ac981e5a7883309d46adeebe92dec);
#
#
#             var marker_010a3ce2284c8e597fb4d0103c35d03c = L.marker(
#                 [34.689117, 135.534195],
#                 {
# }
#             ).addTo(map_48895dcf7975f09c6618f6f9272c24bd);
#
#
#         var popup_9074acbcba8bef84dd785e7c3b320b05 = L.popup({
#   &quot;maxWidth&quot;: 500,
# });
#
#
#
#                 var html_190d4c486c30618a3a7f2aa79d13879c = $(`&lt;div id=&quot;html_190d4c486c30618a3a7f2aa79d13879c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;span style=&quot;color:purple; font-weight:bold; font-size:15px;&quot;&gt; 大阪城ホール&lt;/span&gt;&lt;br /&gt;     &lt;span style=&quot;color:green;font-size:12px;&quot;&gt;
# &lt;br /&gt;2025/04/28 YAKI YAKI YANKEE TOUR 続 「名巧は愚なるが如し」
# &lt;br /&gt;2025/04/29 YAKI YAKI YANKEE TOUR 続 「名巧は愚なるが如し」
# &lt;br /&gt;&lt;/span&gt;     &lt;/div&gt;`)[0];
#                 popup_9074acbcba8bef84dd785e7c3b320b05.setContent(html_190d4c486c30618a3a7f2aa79d13879c);
#
#
#
#         marker_010a3ce2284c8e597fb4d0103c35d03c.bindPopup(popup_9074acbcba8bef84dd785e7c3b320b05)
